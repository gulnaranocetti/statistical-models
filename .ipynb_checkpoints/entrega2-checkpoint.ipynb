# %% [markdown]
# # 1. Generar conjunto de datos sintéticos

# %% [markdown]
# Cargar la matriz de correlación

# %%
import numpy as np
import pandas as pd

cov_matrix = pd.read_csv('mat_cov.csv').values

# %%
np.random.seed(42)

n_samples = 150
n_features = 50

mean = np.zeros(n_features)

# Generar datos sintéticos
X = np.random.multivariate_normal(mean, cov_matrix, size=n_samples)

# Convertir a DataFrame
X_df = pd.DataFrame(X, columns=[f'X{i+1}' for i in range(n_features)])

# %%
X_df.head()
# Out:
#          X1        X2        X3        X4        X5        X6        X7  \
# 0  0.186308 -0.820221  0.422954  0.190821 -1.320801 -0.454796  0.804937
# 1  0.918081  0.025233 -0.178135 -0.653559 -0.742937 -0.724692  0.592756
# 2 -0.943178 -0.355982 -1.254916  0.594678  0.496199 -0.462866 -0.215763
# 3  0.187396 -0.260711 -0.647634 -0.088311 -0.404784 -0.364406  0.354536
# 4 -0.165754 -0.010144  0.395370  0.103226  0.121329  0.070942  1.224411
#
#          X8        X9       X10  ...       X41       X42       X43       X44  \
# 0 -1.703741 -0.353018  0.103973  ... -0.361749  0.678168  0.289063 -0.463401
# 1  0.361891  0.816047  0.347074  ...  0.400291  0.046623  0.095804 -0.347168
# 2  1.047683 -0.133262  0.646307  ... -0.653090  1.054205  0.980147 -0.120957
# 3  0.489012 -0.413760 -1.125269  ... -0.449818  1.208946 -1.079749 -0.031084
# 4 -0.745223 -0.083532  0.851168  ... -0.494927  1.737413 -0.203094 -1.131112
#
#         X45       X46       X47       X48       X49       X50
# 0 -0.146830 -0.146265  1.055668 -0.172807 -0.155737  1.221115
# 1  0.189116  1.255416 -0.712092 -0.358778  0.000080  0.678081
# 2 -0.402486 -1.335639 -1.279100  0.495933  0.321842 -0.505359
# 3  1.052038  0.965266 -0.297255  0.414274 -0.138381  0.552097
# 4  1.543805  0.142476  0.773700  0.760420 -0.345862 -0.146012
#
# [5 rows x 50 columns]

# %% [markdown]
# # 2. Definir una variable objetivo Y

# %%
np.random.seed(42)
n_informativas = 5
n_variables = X.shape[1]

# Índices de las variables informativas
informativas_idx = np.random.choice(n_variables, n_informativas, replace=False)

coeficientes = np.zeros(n_variables)
coeficientes[informativas_idx] = np.random.uniform(1, 5, size=n_informativas)

# Generar Y como combinación lineal + ruido gaussiano
ruido = np.random.normal(loc=0, scale=0.25, size=X.shape[0])
Y = X @ coeficientes + ruido
